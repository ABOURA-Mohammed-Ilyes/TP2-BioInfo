# %% [markdown]
# <h1 style="text-align: center;"> TP 02</h1>
# <h2> OUSLIMANI Hocine</br> ABOURA Mohammed Ilyes</h>

# %%
from Bio import Entrez, SeqIO
from Bio.Seq import Seq
from Bio import pairwise2
from Bio.pairwise2 import format_alignment
from Bio import AlignIO
import os
import pandas as pd
import random
import numpy as np
from tabulate import tabulate
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# Configuration des paramètres
Entrez.email = "getBioPythonSequence@example.com"
types = ["alpha", "beta", "omega", "delta"]
years = [2020, 2021, 2022, 2023, 2024]
num_sequences_to_save = 1  # Nombre de séquences les plus courtes à sauvegarder
sequences_to_fetch = 50  # Nombre de séquences à examiner par recherche

# Longueur minimale des séquences
min_length = 300

# Dossier principal pour stocker les séquences
output_dir = "SARS-CoV-2_Sequences"

# %%
# Fonction pour créer un dossier s'il n'existe pas
def create_folder(path):
    if not os.path.exists(path):
        os.makedirs(path)

# Fonction pour convertir une séquence ADN en ARN
def convert_dna_to_rna(sequence):
    return sequence.replace("T", "U")

# Fonction pour trouver les séquences les plus courtes
def find_shortest_sequences(query):
    print(f"Recherche de {sequences_to_fetch} séquences pour : {query}")
    try:
        # Recherche des séquences dans NCBI
        handle = Entrez.esearch(db="nucleotide", term=query, retmax=sequences_to_fetch)
        record = Entrez.read(handle)
        handle.close()

        id_list = record["IdList"]
        if not id_list:
            print("Aucune séquence trouvée.")
            return []

        # Récupération des séquences
        handle = Entrez.efetch(db="nucleotide", id=id_list, rettype="fasta", retmode="text")
        fasta_records = list(SeqIO.parse(handle, "fasta"))
        handle.close()

        # Affichage des séquences récupérées avec leur taille
        print("\nSéquences récupérées :")
        for record in fasta_records:
            print(f"- ID : {record.id}, Taille : {len(record.seq)} bases")

        # Filtrer les séquences valides (au-dessus de la longueur minimale)
        valid_sequences = [
            record for record in fasta_records if len(record.seq) >= min_length
        ]

        if not valid_sequences:
            print("Aucune séquence valide trouvée.")
            return []

        # Trier par longueur croissante
        valid_sequences.sort(key=lambda record: len(record.seq))

        # Retourner les plus courtes
        return valid_sequences[:num_sequences_to_save]

    except Exception as e:
        print(f"Erreur lors de la récupération des séquences : {e}")
        return []

# Fonction pour télécharger et sauvegarder les séquences depuis NCBI
def download_fasta_sequences():
    for sars_type in types:
        for year in years:
            query = f"SARS-CoV-2 {sars_type} {year}[pdat]"
            print(f"\nRecherche : {query}")

            # Créer le dossier correspondant
            folder_path = os.path.join(output_dir, sars_type, str(year))
            create_folder(folder_path)

            # Trouver les séquences les plus courtes
            shortest_sequences = find_shortest_sequences(query)
            if not shortest_sequences:
                print("Aucune séquence à sauvegarder. Recherche abandonnée pour ce type et cette année.")
                continue

            # Sauvegarder les séquences
            for record in shortest_sequences:
                # Convertir la séquence en ARN
                rna_sequence = convert_dna_to_rna(str(record.seq))

                # Modifier le record pour inclure la séquence ARN
                record.seq = Seq(rna_sequence)

                # Sauvegarder la séquence
                fasta_file = os.path.join(folder_path, f"{record.id}.fasta")
                SeqIO.write(record, fasta_file, "fasta")
                print(f"Séquence ARN sauvegardée : {fasta_file}")

# Lancer le téléchargement
download_fasta_sequences()
# Out:
# Recherche : SARS-CoV-2 alpha 2020[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 alpha 2020[pdat]
#
# Séquences récupérées :
# - ID : NM_001377530.1, Taille : 7984 bases
# - ID : NM_001388412.1, Taille : 6256 bases
# - ID : NM_001388417.1, Taille : 6758 bases
# - ID : NM_001388415.1, Taille : 4594 bases
# - ID : NM_001388414.1, Taille : 4606 bases
# - ID : NM_001388418.1, Taille : 6731 bases
# - ID : NM_001388416.1, Taille : 4567 bases
# - ID : NM_001388419.1, Taille : 16188 bases
# - ID : NM_001388413.1, Taille : 4633 bases
# - ID : NM_001379692.1, Taille : 3996 bases
# - ID : NR_170953.1, Taille : 4693 bases
# - ID : NR_170952.1, Taille : 4654 bases
# - ID : MW027019.1, Taille : 313 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\alpha\2020\MW027019.1.fasta
#
# Recherche : SARS-CoV-2 alpha 2021[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 alpha 2021[pdat]
#
# Séquences récupérées :
# - ID : NM_001394000.1, Taille : 1663 bases
# - ID : NM_001393999.1, Taille : 1637 bases
# - ID : OL689583.1, Taille : 29855 bases
# - ID : OL689430.1, Taille : 29839 bases
# - ID : OL675863.1, Taille : 29871 bases
# - ID : OM060676.1, Taille : 3042 bases
# - ID : OL752444.1, Taille : 29717 bases
# - ID : OL752443.1, Taille : 29717 bases
# - ID : OL752442.1, Taille : 29717 bases
# - ID : OL752441.1, Taille : 29717 bases
# - ID : OL752440.1, Taille : 29717 bases
# - ID : OL701298.1, Taille : 29763 bases
# - ID : OL701297.1, Taille : 29763 bases
# - ID : OL701292.1, Taille : 29763 bases
# - ID : MQ300781.1, Taille : 195 bases
# - ID : OL580735.1, Taille : 29617 bases
# - ID : OL580734.1, Taille : 29805 bases
# - ID : OL580733.1, Taille : 29867 bases
# - ID : OL580732.1, Taille : 29533 bases
# - ID : OL580731.1, Taille : 29812 bases
# - ID : OL549102.1, Taille : 29763 bases
# - ID : OL549101.1, Taille : 29763 bases
# - ID : OL549100.1, Taille : 29763 bases
# - ID : OL549099.1, Taille : 29763 bases
# - ID : OL549098.1, Taille : 29763 bases
# - ID : OL549097.1, Taille : 29763 bases
# - ID : OL549096.1, Taille : 29763 bases
# - ID : OL549095.1, Taille : 29763 bases
# - ID : OL549094.1, Taille : 29763 bases
# - ID : OL549093.1, Taille : 29757 bases
# - ID : OL549091.1, Taille : 29763 bases
# - ID : OL549090.1, Taille : 29763 bases
# - ID : OL548862.1, Taille : 29763 bases
# - ID : OL548860.1, Taille : 29763 bases
# - ID : OL548859.1, Taille : 29763 bases
# - ID : OL548858.1, Taille : 29746 bases
# - ID : OL548857.1, Taille : 29763 bases
# - ID : OL548856.1, Taille : 29757 bases
# - ID : OL548855.1, Taille : 29763 bases
# - ID : OL548854.1, Taille : 29763 bases
# - ID : OL548852.1, Taille : 29763 bases
# - ID : OL548851.1, Taille : 29763 bases
# - ID : OL548850.1, Taille : 29763 bases
# - ID : OL548849.1, Taille : 29763 bases
# - ID : OL548848.1, Taille : 29763 bases
# - ID : OL548847.1, Taille : 29763 bases
# - ID : OL548846.1, Taille : 29763 bases
# - ID : OL546837.1, Taille : 29763 bases
# - ID : OL546836.1, Taille : 29763 bases
# - ID : OL546835.1, Taille : 29763 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\alpha\2021\NM_001393999.1.fasta
#
# Recherche : SARS-CoV-2 alpha 2022[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 alpha 2022[pdat]
#
# Séquences récupérées :
# - ID : NZ_CP053750.1, Taille : 5396718 bases
# - ID : NM_001412594.1, Taille : 4999 bases
# - ID : NR_177269.1, Taille : 1843 bases
# - ID : NR_177267.1, Taille : 1822 bases
# - ID : NR_177268.1, Taille : 1899 bases
# - ID : NR_177270.1, Taille : 1926 bases
# - ID : NR_177272.1, Taille : 1766 bases
# - ID : NM_001411477.1, Taille : 1807 bases
# - ID : NM_001411475.1, Taille : 1641 bases
# - ID : NM_001411481.1, Taille : 2058 bases
# - ID : NM_001411479.1, Taille : 1606 bases
# - ID : NM_001411483.1, Taille : 1981 bases
# - ID : NM_001411480.1, Taille : 1585 bases
# - ID : NM_001411474.1, Taille : 1884 bases
# - ID : NM_001411476.1, Taille : 1863 bases
# - ID : NM_001411482.1, Taille : 1946 bases
# - ID : NM_001411478.1, Taille : 1919 bases
# - ID : NM_001412593.1, Taille : 4903 bases
# - ID : NZ_JAMZBT010000011.1, Taille : 224284 bases
# - ID : NZ_JAMZBU010000004.1, Taille : 375746 bases
# - ID : BSCM01000001.1, Taille : 1916409 bases
# - ID : BSCM01000002.1, Taille : 618379 bases
# - ID : BSCM01000003.1, Taille : 554180 bases
# - ID : BSCM01000004.1, Taille : 358549 bases
# - ID : BSCM01000005.1, Taille : 261976 bases
# - ID : BSCM01000007.1, Taille : 209660 bases
# - ID : BSCM01000010.1, Taille : 112448 bases
# - ID : BSCM01000011.1, Taille : 104631 bases
# - ID : BSCM01000012.1, Taille : 81123 bases
# - ID : BSCM01000013.1, Taille : 63158 bases
# - ID : BSCM01000017.1, Taille : 26319 bases
# - ID : OP646601.1, Taille : 29689 bases
# - ID : OP646600.1, Taille : 29683 bases
# - ID : OP646599.1, Taille : 29683 bases
# - ID : OP646597.1, Taille : 29683 bases
# - ID : OP646596.1, Taille : 29683 bases
# - ID : OP646595.1, Taille : 29683 bases
# - ID : ON908694.1, Taille : 610 bases
# - ID : ON908693.1, Taille : 506 bases
# - ID : ON333670.1, Taille : 29786 bases
# - ID : ON333669.1, Taille : 29699 bases
# - ID : OM687932.1, Taille : 1479 bases
# - ID : OM687926.1, Taille : 1607 bases
# - ID : OM687912.1, Taille : 1482 bases
# - ID : OM687910.1, Taille : 1485 bases
# - ID : OM687904.1, Taille : 1482 bases
# - ID : OM813336.1, Taille : 326 bases
# - ID : OM813335.1, Taille : 369 bases
# - ID : OM813334.1, Taille : 326 bases
# - ID : OM813333.1, Taille : 326 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\alpha\2022\OM813336.1.fasta
#
# Recherche : SARS-CoV-2 alpha 2023[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 alpha 2023[pdat]
#
# Séquences récupérées :
# - ID : NR_187571.1, Taille : 806 bases
# - ID : pdb|8UYJ|A, Taille : 135 bases
# - ID : pdb|8G6R|J, Taille : 20 bases
# - ID : pdb|8G6R|I, Taille : 20 bases
# - ID : NM_001424057.1, Taille : 1838 bases
# - ID : NM_001424056.1, Taille : 2493 bases
# - ID : NM_001424052.1, Taille : 2236 bases
# - ID : NM_001424059.1, Taille : 1889 bases
# - ID : NM_001424058.1, Taille : 1504 bases
# - ID : NM_001424053.1, Taille : 2054 bases
# - ID : NM_001424060.1, Taille : 1673 bases
# - ID : NM_001424061.1, Taille : 1720 bases
# - ID : NM_001424055.1, Taille : 2039 bases
# - ID : NM_001416370.1, Taille : 1673 bases
# - ID : NM_001416369.1, Taille : 1757 bases
# - ID : pdb|8UYP|A, Taille : 143 bases
# - ID : pdb|8UYS|A, Taille : 124 bases
# - ID : pdb|8UYM|A, Taille : 135 bases
# - ID : pdb|8UYL|A, Taille : 135 bases
# - ID : pdb|8UYK|A, Taille : 135 bases
# - ID : pdb|8UYG|A, Taille : 135 bases
# - ID : pdb|8UYE|A, Taille : 135 bases
# - ID : pdb|8URB|J, Taille : 55 bases
# - ID : pdb|8URB|I, Taille : 33 bases
# - ID : OR584241.1, Taille : 29839 bases
# - ID : NZ_BSCM01000003.1, Taille : 554180 bases
# - ID : OP723873.1, Taille : 669 bases
# - ID : LC761361.1, Taille : 423 bases
# - ID : LC761360.1, Taille : 423 bases
# - ID : LC761359.1, Taille : 423 bases
# - ID : LC761358.1, Taille : 423 bases
# - ID : LC761357.1, Taille : 423 bases
# - ID : LC761356.1, Taille : 423 bases
# - ID : LC761355.1, Taille : 423 bases
# - ID : LC761354.1, Taille : 423 bases
# - ID : LC761353.1, Taille : 423 bases
# - ID : LC761352.1, Taille : 423 bases
# - ID : LC761351.1, Taille : 423 bases
# - ID : LC761350.1, Taille : 423 bases
# - ID : LC761349.1, Taille : 423 bases
# - ID : LC761348.1, Taille : 423 bases
# - ID : LC761347.1, Taille : 423 bases
# - ID : LC761346.1, Taille : 423 bases
# - ID : LC761345.1, Taille : 423 bases
# - ID : LC761344.1, Taille : 423 bases
# - ID : LC761343.1, Taille : 423 bases
# - ID : LC761342.1, Taille : 423 bases
# - ID : LC761341.1, Taille : 423 bases
# - ID : LC761340.1, Taille : 423 bases
# - ID : LC761339.1, Taille : 423 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\alpha\2023\LC761361.1.fasta
#
# Recherche : SARS-CoV-2 alpha 2024[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 alpha 2024[pdat]
#
# Séquences récupérées :
# - ID : OP485086.1, Taille : 29758 bases
# - ID : PQ380153.1, Taille : 29754 bases
# - ID : PQ380152.1, Taille : 29772 bases
# - ID : PQ380151.1, Taille : 29766 bases
# - ID : pdb|9CPO|T, Taille : 33 bases
# - ID : pdb|9CPO|P, Taille : 30 bases
# - ID : NM_001428359.1, Taille : 4739 bases
# - ID : NM_001428360.1, Taille : 4696 bases
# - ID : BK066888.1, Taille : 146790 bases
# - ID : BK066332.1, Taille : 703578 bases
# - ID : OR994921.1, Taille : 4408 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\alpha\2024\OR994921.1.fasta
#
# Recherche : SARS-CoV-2 beta 2020[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 beta 2020[pdat]
#
# Séquences récupérées :
# - ID : NM_001377530.1, Taille : 7984 bases
# - ID : NM_001382622.1, Taille : 4243 bases
# - ID : NM_001382619.1, Taille : 4222 bases
# - ID : NM_001382621.1, Taille : 4343 bases
# - ID : NM_001382620.1, Taille : 4182 bases
# - ID : NM_001385663.1, Taille : 11855 bases
# - ID : NR_168464.1, Taille : 4187 bases
# - ID : NG_070884.1, Taille : 1024 bases
# - ID : MT730002.1, Taille : 29872 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\beta\2020\NG_070884.1.fasta
#
# Recherche : SARS-CoV-2 beta 2021[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 beta 2021[pdat]
#
# Séquences récupérées :
# - ID : NM_001394839.1, Taille : 2531 bases
# - ID : NM_001394850.1, Taille : 2622 bases
# - ID : NM_001394853.1, Taille : 5511 bases
# - ID : NM_001394838.1, Taille : 5736 bases
# - ID : NM_001394837.1, Taille : 2550 bases
# - ID : NM_001394857.1, Taille : 2541 bases
# - ID : NM_001394847.1, Taille : 5642 bases
# - ID : NM_001394836.1, Taille : 2558 bases
# - ID : NM_001394854.1, Taille : 5605 bases
# - ID : NM_001394832.1, Taille : 2625 bases
# - ID : NM_001394851.1, Taille : 2346 bases
# - ID : NM_001394843.1, Taille : 2477 bases
# - ID : NM_001394846.1, Taille : 2427 bases
# - ID : NM_001394835.1, Taille : 5784 bases
# - ID : NM_001394841.1, Taille : 5709 bases
# - ID : NM_001394852.1, Taille : 2325 bases
# - ID : NM_001394842.1, Taille : 2480 bases
# - ID : NM_001394848.1, Taille : 2400 bases
# - ID : NM_001394834.1, Taille : 2598 bases
# - ID : NM_001394844.1, Taille : 2456 bases
# - ID : NM_001394858.1, Taille : 2496 bases
# - ID : NM_001394833.1, Taille : 5811 bases
# - ID : NM_001394849.1, Taille : 2649 bases
# - ID : NM_001394860.1, Taille : 2523 bases
# - ID : NM_001394840.1, Taille : 2523 bases
# - ID : NM_001394859.1, Taille : 5578 bases
# - ID : NM_001394855.1, Taille : 2547 bases
# - ID : NM_001394856.1, Taille : 2571 bases
# - ID : NM_001394845.1, Taille : 5669 bases
# - ID : OL689583.1, Taille : 29855 bases
# - ID : OL689430.1, Taille : 29839 bases
# - ID : OL675863.1, Taille : 29871 bases
# - ID : MW626426.1, Taille : 29794 bases
# - ID : MW626425.1, Taille : 29803 bases
# - ID : MW626424.1, Taille : 29803 bases
# - ID : MW626423.1, Taille : 29803 bases
# - ID : MW626422.1, Taille : 29803 bases
# - ID : MW626421.1, Taille : 29802 bases
# - ID : MW626420.1, Taille : 29797 bases
# - ID : MW626419.1, Taille : 29802 bases
# - ID : MW626418.1, Taille : 29802 bases
# - ID : MW626417.1, Taille : 29803 bases
# - ID : MW626416.1, Taille : 29797 bases
# - ID : MW626415.1, Taille : 29802 bases
# - ID : MW626414.1, Taille : 29803 bases
# - ID : MW626413.1, Taille : 29827 bases
# - ID : MW626412.1, Taille : 29803 bases
# - ID : MW626411.1, Taille : 29796 bases
# - ID : MW626410.1, Taille : 29802 bases
# - ID : MW626409.1, Taille : 29797 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\beta\2021\NM_001394852.1.fasta
#
# Recherche : SARS-CoV-2 beta 2022[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 beta 2022[pdat]
#
# Séquences récupérées :
# - ID : NZ_CP053750.1, Taille : 5396718 bases
# - ID : NM_001412594.1, Taille : 4999 bases
# - ID : NM_001410834.1, Taille : 3701 bases
# - ID : NM_001412593.1, Taille : 4903 bases
# - ID : NZ_JAMZBT010000011.1, Taille : 224284 bases
# - ID : NZ_JAMZBT010000007.1, Taille : 350490 bases
# - ID : NZ_JAMZBT010000002.1, Taille : 688796 bases
# - ID : NZ_JAMZBU010000005.1, Taille : 357642 bases
# - ID : NZ_JAMZBU010000004.1, Taille : 375746 bases
# - ID : NZ_JAMZBU010000002.1, Taille : 1019644 bases
# - ID : BSCM01000001.1, Taille : 1916409 bases
# - ID : BSCM01000002.1, Taille : 618379 bases
# - ID : BSCM01000004.1, Taille : 358549 bases
# - ID : BSCM01000005.1, Taille : 261976 bases
# - ID : BSCM01000006.1, Taille : 229748 bases
# - ID : BSCM01000007.1, Taille : 209660 bases
# - ID : BSCM01000011.1, Taille : 104631 bases
# - ID : BSCM01000013.1, Taille : 63158 bases
# - ID : BSCM01000016.1, Taille : 29089 bases
# - ID : OP646598.1, Taille : 29684 bases
# - ID : PA544048.1, Taille : 703 bases
# - ID : PA543487.1, Taille : 703 bases
# - ID : ON262565.1, Taille : 9727 bases
# - ID : ON262564.1, Taille : 15227 bases
# - ID : OM814165.1, Taille : 128 bases
# - ID : OM814164.1, Taille : 146 bases
# - ID : OM814163.1, Taille : 125 bases
# - ID : OM814162.1, Taille : 145 bases
# - ID : OM814161.1, Taille : 127 bases
# - ID : OM814160.1, Taille : 129 bases
# - ID : OM814159.1, Taille : 129 bases
# - ID : OM814158.1, Taille : 133 bases
# - ID : OM814157.1, Taille : 133 bases
# - ID : OM814156.1, Taille : 127 bases
# - ID : OM814155.1, Taille : 142 bases
# - ID : OM814154.1, Taille : 141 bases
# - ID : OM814153.1, Taille : 129 bases
# - ID : OM814152.1, Taille : 186 bases
# - ID : OM814151.1, Taille : 126 bases
# - ID : OM814150.1, Taille : 133 bases
# - ID : OM814149.1, Taille : 185 bases
# - ID : OM814148.1, Taille : 138 bases
# - ID : OM814147.1, Taille : 128 bases
# - ID : OM814146.1, Taille : 126 bases
# - ID : OM814145.1, Taille : 193 bases
# - ID : OM814144.1, Taille : 134 bases
# - ID : OM814143.1, Taille : 132 bases
# - ID : OM814142.1, Taille : 132 bases
# - ID : OM814141.1, Taille : 188 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\beta\2022\PA544048.1.fasta
#
# Recherche : SARS-CoV-2 beta 2023[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 beta 2023[pdat]
#
# Séquences récupérées :
# - ID : NM_001417890.1, Taille : 3799 bases
# - ID : OR936719.1, Taille : 29840 bases
# - ID : OR578390.1, Taille : 29805 bases
# - ID : NZ_BSCM01000003.1, Taille : 554180 bases
# - ID : NZ_BSCM01000001.1, Taille : 1916409 bases
# - ID : OQ624932.1, Taille : 733 bases
# - ID : OP697994.1, Taille : 9695 bases
# - ID : OP697993.1, Taille : 9768 bases
# - ID : OP697992.1, Taille : 9181 bases
# - ID : OP697991.1, Taille : 9868 bases
# - ID : OP697990.1, Taille : 5237 bases
# - ID : OP697989.1, Taille : 10787 bases
# - ID : OP697988.1, Taille : 10200 bases
# - ID : OP697987.1, Taille : 11130 bases
# - ID : OP697986.1, Taille : 6256 bases
# - ID : OP697985.1, Taille : 4895 bases
# - ID : ON755133.1, Taille : 4326 bases
# - ID : ON755132.1, Taille : 4326 bases
# - ID : ON755131.1, Taille : 4326 bases
# - ID : OQ568810.1, Taille : 29718 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\beta\2023\OQ624932.1.fasta
#
# Recherche : SARS-CoV-2 beta 2024[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 beta 2024[pdat]
#
# Séquences récupérées :
# - ID : NM_001433977.1, Taille : 5667 bases
# - ID : NM_001433974.1, Taille : 5595 bases
# - ID : NM_001433975.1, Taille : 5616 bases
# - ID : NM_001433976.1, Taille : 5646 bases
# - ID : BK066332.1, Taille : 703578 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\beta\2024\NM_001433974.1.fasta
#
# Recherche : SARS-CoV-2 omega 2020[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 omega 2020[pdat]
#
# Séquences récupérées :
# - ID : NM_001378219.1, Taille : 3193 bases
# - ID : NM_001378218.1, Taille : 3193 bases
# - ID : NM_001378220.1, Taille : 3166 bases
# - ID : NM_001376057.1, Taille : 6711 bases
# - ID : NM_001376056.1, Taille : 3626 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\omega\2020\NM_001378220.1.fasta
#
# Recherche : SARS-CoV-2 omega 2021[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 omega 2021[pdat]
#
# Séquences récupérées :
# - ID : NM_001391956.1, Taille : 6792 bases
# - ID : NM_001391953.1, Taille : 6464 bases
# - ID : NM_001391941.1, Taille : 6960 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\omega\2021\NM_001391953.1.fasta
#
# Recherche : SARS-CoV-2 omega 2022[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 omega 2022[pdat]
#
# Séquences récupérées :
# - ID : NM_001400007.1, Taille : 4411 bases
# - ID : NM_001400010.1, Taille : 4199 bases
# - ID : NM_001400008.1, Taille : 4262 bases
# - ID : NM_001400006.1, Taille : 4532 bases
# - ID : NM_001400005.1, Taille : 4400 bases
# - ID : NM_001400004.1, Taille : 4279 bases
# - ID : NM_001400011.1, Taille : 4345 bases
# - ID : NM_001400012.1, Taille : 4313 bases
# - ID : NM_001413758.1, Taille : 2494 bases
# - ID : BSCM01000005.1, Taille : 261976 bases
# - ID : OM193659.1, Taille : 29776 bases
# - ID : CP053750.1, Taille : 5396718 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\omega\2022\NM_001413758.1.fasta
#
# Recherche : SARS-CoV-2 omega 2023[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 omega 2023[pdat]
# Aucune séquence trouvée.
# Aucune séquence à sauvegarder. Recherche abandonnée pour ce type et cette année.
#
# Recherche : SARS-CoV-2 omega 2024[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 omega 2024[pdat]
# Aucune séquence trouvée.
# Aucune séquence à sauvegarder. Recherche abandonnée pour ce type et cette année.
#
# Recherche : SARS-CoV-2 delta 2020[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 delta 2020[pdat]
#
# Séquences récupérées :
# - ID : MW027018.1, Taille : 444 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\delta\2020\MW027018.1.fasta
#
# Recherche : SARS-CoV-2 delta 2021[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 delta 2021[pdat]
#
# Séquences récupérées :
# - ID : NM_001389562.1, Taille : 4128 bases
# - ID : NM_001389563.1, Taille : 3521 bases
# - ID : OL622105.1, Taille : 29871 bases
# - ID : OK555092.4, Taille : 29852 bases
# - ID : OM060237.1, Taille : 29769 bases
# - ID : OM061695.1, Taille : 29858 bases
# - ID : OM019073.1, Taille : 29769 bases
# - ID : OL739245.1, Taille : 29769 bases
# - ID : OL721911.1, Taille : 29770 bases
# - ID : OL721910.1, Taille : 29774 bases
# - ID : OL721909.1, Taille : 29679 bases
# - ID : OL721908.1, Taille : 29769 bases
# - ID : OL721907.1, Taille : 29769 bases
# - ID : OL721906.1, Taille : 29769 bases
# - ID : OL721905.1, Taille : 29772 bases
# - ID : OL721904.1, Taille : 29769 bases
# - ID : OL721903.1, Taille : 29769 bases
# - ID : OL638175.1, Taille : 29763 bases
# - ID : OL638173.1, Taille : 29816 bases
# - ID : OL638172.1, Taille : 29816 bases
# - ID : OL638171.1, Taille : 29822 bases
# - ID : OL638170.1, Taille : 29822 bases
# - ID : OL638169.1, Taille : 29816 bases
# - ID : OL638168.1, Taille : 29816 bases
# - ID : OL638167.1, Taille : 29816 bases
# - ID : OL638166.1, Taille : 29816 bases
# - ID : OL638165.1, Taille : 29816 bases
# - ID : OL638164.1, Taille : 29816 bases
# - ID : OL638163.1, Taille : 29816 bases
# - ID : OL638162.1, Taille : 29810 bases
# - ID : OL589643.1, Taille : 29769 bases
# - ID : OL589642.1, Taille : 29769 bases
# - ID : OL589641.1, Taille : 29769 bases
# - ID : OL589640.1, Taille : 29769 bases
# - ID : OL546796.1, Taille : 29769 bases
# - ID : OL546795.1, Taille : 29769 bases
# - ID : OL546794.1, Taille : 29769 bases
# - ID : OL546793.1, Taille : 29769 bases
# - ID : OL546723.1, Taille : 29769 bases
# - ID : OL546722.1, Taille : 29769 bases
# - ID : OL546721.1, Taille : 29769 bases
# - ID : OL546720.1, Taille : 29769 bases
# - ID : OL546718.1, Taille : 29769 bases
# - ID : OL546717.1, Taille : 29769 bases
# - ID : OL546716.1, Taille : 29769 bases
# - ID : OL546715.1, Taille : 29769 bases
# - ID : OL546714.1, Taille : 29769 bases
# - ID : OL546713.1, Taille : 29769 bases
# - ID : OL546712.1, Taille : 29769 bases
# - ID : OL546711.1, Taille : 29769 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\delta\2021\NM_001389563.1.fasta
#
# Recherche : SARS-CoV-2 delta 2022[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 delta 2022[pdat]
#
# Séquences récupérées :
# - ID : BSCM01000001.1, Taille : 1916409 bases
# - ID : BSCM01000005.1, Taille : 261976 bases
# - ID : OQ091234.1, Taille : 29785 bases
# - ID : OQ091233.1, Taille : 29790 bases
# - ID : OQ091232.1, Taille : 29778 bases
# - ID : OQ091231.1, Taille : 29777 bases
# - ID : OQ091230.1, Taille : 29777 bases
# - ID : OQ091229.1, Taille : 29772 bases
# - ID : OQ091228.1, Taille : 29722 bases
# - ID : OQ091227.1, Taille : 29733 bases
# - ID : OQ091226.1, Taille : 29457 bases
# - ID : OQ091225.1, Taille : 29779 bases
# - ID : OQ091224.1, Taille : 29734 bases
# - ID : OQ091223.1, Taille : 29778 bases
# - ID : OQ091222.1, Taille : 29782 bases
# - ID : OQ091221.1, Taille : 29617 bases
# - ID : OQ091220.1, Taille : 29777 bases
# - ID : OQ091219.1, Taille : 29786 bases
# - ID : OQ091218.1, Taille : 29525 bases
# - ID : OQ091217.1, Taille : 29715 bases
# - ID : OQ091216.1, Taille : 29794 bases
# - ID : OQ091215.1, Taille : 29672 bases
# - ID : OQ091214.1, Taille : 29765 bases
# - ID : OQ091213.1, Taille : 29783 bases
# - ID : OQ091212.1, Taille : 29786 bases
# - ID : OQ091211.1, Taille : 29780 bases
# - ID : OQ091210.1, Taille : 29786 bases
# - ID : OQ091209.1, Taille : 29784 bases
# - ID : OQ091208.1, Taille : 29747 bases
# - ID : OQ091207.1, Taille : 29775 bases
# - ID : OQ091206.1, Taille : 29783 bases
# - ID : OQ091205.1, Taille : 29784 bases
# - ID : OQ091204.1, Taille : 29804 bases
# - ID : OQ091203.1, Taille : 29735 bases
# - ID : OQ091202.1, Taille : 29777 bases
# - ID : OQ091201.1, Taille : 29742 bases
# - ID : OQ091200.1, Taille : 29803 bases
# - ID : OQ091199.1, Taille : 29801 bases
# - ID : OQ091198.1, Taille : 29780 bases
# - ID : OQ091197.1, Taille : 29782 bases
# - ID : OQ091196.1, Taille : 29784 bases
# - ID : OQ091195.1, Taille : 29786 bases
# - ID : OQ091194.1, Taille : 29797 bases
# - ID : OQ091193.1, Taille : 29785 bases
# - ID : OQ091192.1, Taille : 29783 bases
# - ID : OQ091191.1, Taille : 29783 bases
# - ID : OQ091190.1, Taille : 29780 bases
# - ID : OQ091189.1, Taille : 29780 bases
# - ID : OQ091188.1, Taille : 29463 bases
# - ID : OQ091187.1, Taille : 29799 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\delta\2022\OQ091226.1.fasta
#
# Recherche : SARS-CoV-2 delta 2023[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 delta 2023[pdat]
#
# Séquences récupérées :
# - ID : OR936720.1, Taille : 29852 bases
# - ID : OR607962.1, Taille : 29869 bases
# - ID : OR575633.1, Taille : 29850 bases
# - ID : ON725040.1, Taille : 29878 bases
# - ID : ON545851.1, Taille : 29770 bases
# - ID : OQ700911.1, Taille : 1602 bases
# - ID : OQ608212.1, Taille : 1260 bases
# - ID : OQ608211.1, Taille : 1260 bases
# - ID : OQ608210.1, Taille : 1260 bases
# - ID : OQ608209.1, Taille : 1260 bases
# - ID : OQ608208.1, Taille : 1260 bases
# - ID : OQ608207.1, Taille : 1260 bases
# - ID : OQ608206.1, Taille : 1260 bases
# - ID : OQ608205.1, Taille : 1260 bases
# - ID : OQ608204.1, Taille : 1260 bases
# - ID : OQ608203.1, Taille : 1260 bases
# - ID : OQ608202.1, Taille : 1260 bases
# - ID : OQ608201.1, Taille : 1260 bases
# - ID : OQ608200.1, Taille : 1260 bases
# - ID : OQ608199.1, Taille : 1260 bases
# - ID : OQ608198.1, Taille : 1260 bases
# - ID : OQ608197.1, Taille : 1260 bases
# - ID : OQ608196.1, Taille : 1260 bases
# - ID : OQ608195.1, Taille : 1260 bases
# - ID : OQ608194.1, Taille : 1260 bases
# - ID : OQ608193.1, Taille : 1260 bases
# - ID : OQ608192.1, Taille : 1260 bases
# - ID : OQ608191.1, Taille : 1260 bases
# - ID : OQ608190.1, Taille : 1260 bases
# - ID : OQ608189.1, Taille : 1260 bases
# - ID : OQ608188.1, Taille : 1260 bases
# - ID : OQ608187.1, Taille : 1260 bases
# - ID : OQ608186.1, Taille : 1260 bases
# - ID : OQ608185.1, Taille : 1260 bases
# - ID : OQ608184.1, Taille : 1260 bases
# - ID : OQ608183.1, Taille : 1260 bases
# - ID : OQ608182.1, Taille : 1260 bases
# - ID : OQ608181.1, Taille : 1260 bases
# - ID : OQ608180.1, Taille : 1260 bases
# - ID : OQ608179.1, Taille : 1260 bases
# - ID : OQ608178.1, Taille : 1260 bases
# - ID : OQ608177.1, Taille : 1260 bases
# - ID : OQ608176.1, Taille : 1260 bases
# - ID : OQ608175.1, Taille : 1260 bases
# - ID : OQ608174.1, Taille : 1260 bases
# - ID : OQ608173.1, Taille : 1260 bases
# - ID : OQ608172.1, Taille : 1260 bases
# - ID : OQ608171.1, Taille : 1260 bases
# - ID : OQ608170.1, Taille : 1260 bases
# - ID : OQ608169.1, Taille : 1260 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\delta\2023\OQ608212.1.fasta
#
# Recherche : SARS-CoV-2 delta 2024[pdat]
# Recherche de 50 séquences pour : SARS-CoV-2 delta 2024[pdat]
#
# Séquences récupérées :
# - ID : PF167398.1, Taille : 3816 bases
# - ID : PF167396.1, Taille : 3816 bases
# - ID : OP485087.1, Taille : 29873 bases
# - ID : PQ380153.1, Taille : 29754 bases
# - ID : PQ380152.1, Taille : 29772 bases
# - ID : PQ380151.1, Taille : 29766 bases
# - ID : PP942171.1, Taille : 29886 bases
# - ID : PP212968.1, Taille : 1140 bases
# - ID : PP522474.1, Taille : 29796 bases
# - ID : PP522473.1, Taille : 29777 bases
# - ID : PP522472.1, Taille : 29771 bases
# - ID : PP522471.1, Taille : 29765 bases
# - ID : PP522470.1, Taille : 29862 bases
# - ID : PP522469.1, Taille : 29852 bases
# - ID : PP522468.1, Taille : 29771 bases
# - ID : PP522467.1, Taille : 29808 bases
# - ID : PP522466.1, Taille : 29808 bases
# - ID : PP522465.1, Taille : 29777 bases
# - ID : PP522464.1, Taille : 29759 bases
# - ID : PP522463.1, Taille : 29796 bases
# - ID : PP522462.1, Taille : 29805 bases
# - ID : PP522461.1, Taille : 29777 bases
# - ID : PP522460.1, Taille : 29805 bases
# - ID : PP522459.1, Taille : 29796 bases
# - ID : PP522458.1, Taille : 29805 bases
# - ID : PP522457.1, Taille : 29814 bases
# - ID : PP522456.1, Taille : 29805 bases
# - ID : PP522455.1, Taille : 29759 bases
# - ID : PP522454.1, Taille : 29805 bases
# - ID : PP522453.1, Taille : 29840 bases
# - ID : PP522452.1, Taille : 29796 bases
# - ID : PP522451.1, Taille : 29803 bases
# - ID : PP522450.1, Taille : 29805 bases
# - ID : PP522449.1, Taille : 29756 bases
# - ID : PP522448.1, Taille : 29759 bases
# - ID : PP522447.1, Taille : 29759 bases
# - ID : PP522446.1, Taille : 29805 bases
# - ID : PP522445.1, Taille : 29768 bases
# - ID : PP522444.1, Taille : 29805 bases
# - ID : PP522443.1, Taille : 29768 bases
# - ID : PP522442.1, Taille : 29768 bases
# - ID : PP522441.1, Taille : 29768 bases
# - ID : PP522440.1, Taille : 29797 bases
# - ID : PP522439.1, Taille : 29804 bases
# - ID : PP522438.1, Taille : 29768 bases
# - ID : PP522437.1, Taille : 29796 bases
# - ID : PP522436.1, Taille : 29796 bases
# - ID : PP522435.1, Taille : 29750 bases
# - ID : PP522434.1, Taille : 29759 bases
# - ID : PP522433.1, Taille : 29803 bases
# Séquence ARN sauvegardée : SARS-CoV-2_Sequences\delta\2024\PP212968.1.fasta

# %%
# Fonction pour calculer le pourcentage de chaque base
def calculate_base_percentages(sequence):
    total_bases = len(sequence)
    if total_bases == 0:
        return {"A": 0, "U": 0, "C": 0, "G": 0}

    percentages = {
        "A": (sequence.count("A") / total_bases) * 100,
        "U": (sequence.count("U") / total_bases) * 100,
        "C": (sequence.count("C") / total_bases) * 100,
        "G": (sequence.count("G") / total_bases) * 100,
    }
    return percentages

# Fonction pour afficher les informations des séquences
def display_sequence_info():
    # Récupérer toutes les séquences sauvegardées
    sequence_data = []

    for sars_type in types:
        for year in years:
            folder_path = os.path.join(output_dir, sars_type, str(year))
            if not os.path.exists(folder_path):
                continue

            # Charger les fichiers FASTA dans ce dossier
            fasta_files = [
                f for f in os.listdir(folder_path) if f.endswith(".fasta")
            ]

            for fasta_file in fasta_files:
                file_path = os.path.join(folder_path, fasta_file)
                record = SeqIO.read(file_path, "fasta")

                # Calculer les pourcentages de bases
                base_percentages = calculate_base_percentages(str(record.seq))

                # Ajouter les données au tableau
                sequence_data.append({
                    "ID": record.id,
                    "Année": year,
                    "Variant": sars_type,
                    "Longueur": len(record.seq),
                    "A (%)": f"{base_percentages['A']:.2f}",
                    "U (%)": f"{base_percentages['U']:.2f}",
                    "C (%)": f"{base_percentages['C']:.2f}",
                    "G (%)": f"{base_percentages['G']:.2f}",
                    "Description": record.description,
                    "Séquence": str(record.seq),
                })

    # Convertir les données en DataFrame pour un affichage propre
    df = pd.DataFrame(sequence_data)

    # Utiliser tabulate pour un affichage propre dans la console
    print(tabulate(df, headers="keys", tablefmt="grid"))

    # Retourner le DataFrame pour d'autres usages si nécessaire
    return df

# Appeler la fonction pour afficher les informations
df_sequences = display_sequence_info()
# Out:
# +----+----------------+---------+-----------+------------+---------+---------+---------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |    | ID             |   Année | Variant   |   Longueur |   A (%) |   U (%) |   C (%) |   G (%) | Description                                                                                                                                                                                                                                                                                                                                                                                                                            | Séquence                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# +====+================+=========+===========+============+=========+=========+=========+=========+========================================================================================================================================================================================================================================================================================================================================================================================================================================+===================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# |  0 | MW027019.1     |    2020 | alpha     |        313 |   25.24 |   28.43 |   24.6  |   21.73 | MW027019.1 Histoplasma capsulatum strain DMic 206235 alpha tubulin (TUB1) gene, partial cds                                                                                                                                                                                                                                                                                                                                            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# +----+----------------+---------+-----------+------------+---------+---------+---------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |  1 | NM_001393999.1 |    2021 | alpha     |       1637 |   26.51 |   27.98 |   22.72 |   22.79 | NM_001393999.1 Homo sapiens X-box binding protein 1 (XBP1), transcript variant 3, mRNA                                                                                                                                                                                                                                                                                                                                                 | ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# +----+----------------+---------+-----------+------------+---------+---------+---------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |  2 | OM813336.1     |    2022 | alpha     |        326 |   32.21 |   23.62 |   24.54 |   19.63 | OM813336.1 UNVERIFIED: Homo sapiens isolate CP24_D29post-prime_P7_E12 TCR alpha mRNA, partial sequence                                                                                                                                                                                                                                                                                                                                 |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# +----+----------------+---------+-----------+------------+---------+---------+---------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |  3 | LC761361.1     |    2023 | alpha     |        423 |   23.88 |   24.59 |   25.3  |   26.24 | LC761361.1 Mus musculus N217 ighv mRNA for immunoglobulin heavy chain variable region, partial cds                                                                                                                                                                                                                                                                                                                                     | ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# +----+----------------+---------+-----------+------------+---------+---------+---------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# ...
# +----+----------------+---------+-----------+------------+---------+---------+---------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# | 17 | PP212968.1     |    2024 | delta     |       1140 |   29.04 |   31.23 |   26.67 |   12.89 | PP212968.1 Artibeus jamaicensis jamaicensis cytochrome b gene, complete cds; mitochondrial                                                                                                                                                                                                                                                                                                                                             | ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# +----+----------------+---------+-----------+------------+---------+---------+---------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
# Charger un fichier FASTA dans un dossier, avec position par défaut
def get_fasta_by_position(output_dir, variant, year, position=0):
    folder_path = os.path.join(output_dir, variant, year)
    if not os.path.exists(folder_path):
        raise FileNotFoundError(f"Le dossier {folder_path} n'existe pas.")
    
    fasta_files = [f for f in os.listdir(folder_path) if f.endswith(".fasta")]
    if not fasta_files:
        raise FileNotFoundError(f"Aucun fichier FASTA trouvé dans le dossier {folder_path}.")
    
    if position < 0 or position >= len(fasta_files):
        raise IndexError(f"Position invalide : {position}. Il y a {len(fasta_files)} fichier(s) FASTA disponible(s).")
    
    # Sélectionner le fichier FASTA à la position donnée
    fasta_file = fasta_files[position]
    fasta_path = os.path.join(folder_path, fasta_file)
    print(f"Chargement du fichier FASTA : {fasta_path}")
    
    # Charger la séquence
    record = SeqIO.read(fasta_path, "fasta")
    return str(record.seq)

# %%
# Fonction pour l'alignement global (Needleman-Wunsch) avec affichage du score
def global_alignment(seq1, seq2, match_score=1, mismatch_penalty=-1, gap_penalty=-2):
    m = len(seq1)
    n = len(seq2)
    
    # Initialisation de la matrice de score
    score_matrix = [[0 for j in range(n+1)] for i in range(m+1)]
    
    # Initialisation des premières lignes et colonnes avec les pénalités de gap
    for i in range(1, m+1):
        score_matrix[i][0] = gap_penalty * i
    for j in range(1, n+1):
        score_matrix[0][j] = gap_penalty * j
    
    # Remplissage de la matrice de score
    for i in range(1, m+1):
        for j in range(1, n+1):
            if seq1[i-1] == seq2[j-1]:
                diag = score_matrix[i-1][j-1] + match_score
            else:
                diag = score_matrix[i-1][j-1] + mismatch_penalty
            up = score_matrix[i-1][j] + gap_penalty
            left = score_matrix[i][j-1] + gap_penalty
            score_matrix[i][j] = max(diag, up, left)
    
    # Traceback pour obtenir l'alignement
    align1 = ""
    align2 = ""
    i = m
    j = n
    alignment_score = score_matrix[i][j]  # Le score final de l'alignement global
    
    while i > 0 or j > 0:
        current_score = score_matrix[i][j]
        if i > 0 and j > 0 and ((seq1[i-1] == seq2[j-1] and current_score == score_matrix[i-1][j-1] + match_score) or
                                (seq1[i-1] != seq2[j-1] and current_score == score_matrix[i-1][j-1] + mismatch_penalty)):
            align1 = seq1[i-1] + align1
            align2 = seq2[j-1] + align2
            i -= 1
            j -= 1
        elif i > 0 and current_score == score_matrix[i-1][j] + gap_penalty:
            align1 = seq1[i-1] + align1
            align2 = "-" + align2
            i -= 1
        else:
            align1 = "-" + align1
            align2 = seq2[j-1] + align2
            j -= 1
    
    return align1, align2, alignment_score

# Fonction pour l'alignement local (Smith-Waterman) avec affichage du score
def local_alignment(seq1, seq2, match_score=1, mismatch_penalty=-1, gap_penalty=-2):
    m = len(seq1)
    n = len(seq2)
    
    # Initialisation de la matrice de score
    score_matrix = [[0 for j in range(n+1)] for i in range(m+1)]
    max_score = 0
    max_pos = (0, 0)
    
    # Remplissage de la matrice de score
    for i in range(1, m+1):
        for j in range(1, n+1):
            if seq1[i-1] == seq2[j-1]:
                diag = score_matrix[i-1][j-1] + match_score
            else:
                diag = score_matrix[i-1][j-1] + mismatch_penalty
            up = score_matrix[i-1][j] + gap_penalty
            left = score_matrix[i][j-1] + gap_penalty
            score_matrix[i][j] = max(0, diag, up, left)
            if score_matrix[i][j] > max_score:
                max_score = score_matrix[i][j]
                max_pos = (i, j)
    
    # Traceback pour obtenir l'alignement
    align1 = ""
    align2 = ""
    i, j = max_pos
    alignment_score = max_score  # Le score final de l'alignement local
    
    while score_matrix[i][j] != 0:
        current_score = score_matrix[i][j]
        if i > 0 and j > 0 and ((seq1[i-1] == seq2[j-1] and current_score == score_matrix[i-1][j-1] + match_score) or
                                (seq1[i-1] != seq2[j-1] and current_score == score_matrix[i-1][j-1] + mismatch_penalty)):
            align1 = seq1[i-1] + align1
            align2 = seq2[j-1] + align2
            i -= 1
            j -= 1
        elif i > 0 and current_score == score_matrix[i-1][j] + gap_penalty:
            align1 = seq1[i-1] + align1
            align2 = "-" + align2
            i -= 1
        elif j > 0 and current_score == score_matrix[i][j-1] + gap_penalty:
            align1 = "-" + align1
            align2 = seq2[j-1] + align2
            j -= 1
        else:
            break  # Si le score est 0, on arrête le traceback
    
    return align1, align2, alignment_score


# Séquences de test
seq1 = "AGTACGCA"
seq2 = "TATGC"

# Alignement global
align1_global, align2_global, score_global = global_alignment(seq1, seq2)
print("Alignement Global :")
print(align1_global)
print(align2_global)
print(f"Score d'alignement global : {score_global}")

# Alignement local
align1_local, align2_local, score_local = local_alignment(seq1, seq2)
print("\nAlignement Local :")
print(align1_local)
print(align2_local)
print(f"Score d'alignement local : {score_local}")
# Out:
# Alignement Global :
# AGTACGCA
# --TATGC-
# Score d'alignement global : -3
#
# Alignement Local :
# TACGC
# TATGC
# Score d'alignement local : 3

# %%
# Récupération des séquences à partir des fichiers FASTA
seq1 = get_fasta_by_position(output_dir, 'alpha', '2020', position=0)
seq2 = get_fasta_by_position(output_dir, 'beta', '2022', position=0)

# Alignement global
align1_global, align2_global, score_global = global_alignment(seq1, seq2)
print("Alignement Global :")
print(align1_global)
print(align2_global)
print(f"Score d'alignement global : {score_global}")

# Alignement local
align1_local, align2_local, score_local = local_alignment(seq1, seq2)
print("\nAlignement Local :")
print(align1_local)
print(align2_local)
print(f"Score d'alignement local : {score_local}")
# Out:
# Chargement du fichier FASTA : SARS-CoV-2_Sequences\alpha\2020\MW027019.1.fasta
# Chargement du fichier FASTA : SARS-CoV-2_Sequences\beta\2022\PA544048.1.fasta
# Alignement Global :
# ------UG----G---UG-----G--C-CAA----------------AU--C-GC----AA-AC-UC---C---UGC-UG--GGA--GGUAUGA-CUUAA-UCCU-AUC---C-----G--G-----GAAC--UA-U-U----GUUUUC---------C--C---A-----UAU---A----GC-GC-CA-U-UACA-ACAG-C-CAAU-AUAG-A-UUUC--U-AUUGA-UGCUA---AUG-------G-C--U-UG---------G--------A----U-UUA-C--------CU---UU----U-----AU-AU-A-G----UUGU-A----U---------UG------C-------C-U-GG----A--AC-A---U-G--GCA-UU---C-AG---GUA----A-A-U-AUAUA-UC--CCU-AACC----G--GUCGAUG----G-G--------A-UUCUAUGC-----GGCCUA-U----U-CCACCU-G-----C-GC-CC--UAA-CGCACACU-C--GG--GA------UU-U-GA-GA--C---C---A-AU---U-U--G--ACUA-ACUG-UUCC----U-CC---U-C--------GGCA-G--CC-CGA-CGGAUA--CCUG-A---C-----U-G----A-GGA-AC------G-G-A--A--A-G--C---------U-G--C
# ...
# Score d'alignement global : -555
#
# Alignement Local :
# UUUACCUUUUAUAUAGUUGUAUUGCCUGGAAC
# UUUACCUUUUACA-A-UU-AAUUGCCAGGAAC
# Score d'alignement local : 17

# %%
# Séquences de test
sequences = [
    "AGTACGCA",
    "TATGC",
    "ATGACGCA"
]

# Fonction pour effectuer des alignements pair par pair
def pairwise_alignments(sequences):
    num_sequences = len(sequences)
    pairwise_results = []
    
    for i in range(num_sequences):
        for j in range(i+1, num_sequences):
            seq1 = sequences[i]
            seq2 = sequences[j]
            
            # Alignement global
            align1_global, align2_global, score_global = global_alignment(seq1, seq2)
            
            # Alignement local
            align1_local, align2_local, score_local = local_alignment(seq1, seq2)
            
            # Stocker les résultats
            result = {
                'seq1_id': f"Sequence_{i+1}",
                'seq2_id': f"Sequence_{j+1}",
                'global_alignment': (align1_global, align2_global),
                'global_score': score_global,
                'local_alignment': (align1_local, align2_local),
                'local_score': score_local
            }
            pairwise_results.append(result)
    
    return pairwise_results

# %%
# Fonction pour créer un alignement initial avec des gaps insérés aléatoirement
def create_initial_alignment(sequences, max_length):
    aligned_sequences = []
    for seq in sequences:
        seq = list(seq)
        # Ajouter des gaps pour atteindre la longueur maximale
        while len(seq) < max_length:
            pos = random.randint(0, len(seq))
            seq.insert(pos, '-')
        aligned_sequences.append(seq)
    return aligned_sequences

# Fonction pour calculer le score d'un alignement multiple
def alignment_score(aligned_sequences, match_score=1, mismatch_penalty=-1, gap_penalty=-2):
    score = 0
    num_sequences = len(aligned_sequences)
    length = len(aligned_sequences[0])
    for i in range(length):
        column = [seq[i] for seq in aligned_sequences]
        for j in range(num_sequences):
            for k in range(j+1, num_sequences):
                if column[j] == column[k]:
                    if column[j] != '-':
                        score += match_score
                elif column[j] == '-' or column[k] == '-':
                    score += gap_penalty
                else:
                    score += mismatch_penalty
    return score

# Fonction pour effectuer une mutation sur un alignement
def mutate_alignment(aligned_sequences):
    mutated_sequences = []
    for seq in aligned_sequences:
        seq = seq.copy()
        if random.random() < 0.1:  # Probabilité de mutation
            pos1 = random.randint(0, len(seq)-1)
            pos2 = random.randint(0, len(seq)-1)
            seq[pos1], seq[pos2] = seq[pos2], seq[pos1]
        mutated_sequences.append(seq)
    return mutated_sequences

# Fonction principale pour l'algorithme génétique
def genetic_algorithm_msa(sequences, population_size=10, generations=50):
    max_length = max(len(seq) for seq in sequences)
    # Initialisation de la population
    population = [create_initial_alignment(sequences, max_length) for _ in range(population_size)]
    
    best_alignment = None
    best_score = float('-inf')
    
    for generation in range(generations):
        # Calcul des scores pour chaque alignement
        scored_population = [(alignment, alignment_score(alignment)) for alignment in population]
        # Tri par score décroissant
        scored_population.sort(key=lambda x: x[1], reverse=True)
        # Conservation des meilleurs alignements
        population = [alignment for alignment, score in scored_population[:population_size//2]]
        
        # Mise à jour du meilleur alignement
        if scored_population[0][1] > best_score:
            best_score = scored_population[0][1]
            best_alignment = scored_population[0][0]
            print(f"Generation {generation}, Best Score: {best_score}")
        
        # Génération de nouveaux alignements par mutation
        new_population = population.copy()
        while len(new_population) < population_size:
            alignment = random.choice(population)
            mutated_alignment = mutate_alignment(alignment)
            new_population.append(mutated_alignment)
        
        population = new_population
    
    return best_alignment, best_score

# %%
# Fonction pour écrire les séquences dans un fichier FASTA
def write_fasta_file(sequences, file_name):
    with open(file_name, 'w') as f:
        for idx, seq in enumerate(sequences):
            f.write(f">Sequence_{idx+1}\n")
            f.write(seq + "\n")

import subprocess

# Fonction pour exécuter ClustalW
def run_clustalw(fasta_file):
    clustalw_exe = 'clustalw2'  # Assurez-vous que le nom correspond à votre installation
    try:
        subprocess.run([clustalw_exe, '-INFILE=' + fasta_file], check=True)
    except subprocess.CalledProcessError as e:
        print("Erreur lors de l'exécution de ClustalW :", e)

# Fonction pour lire le fichier d'alignement ClustalW
def read_clustalw_alignment(aln_file):
    alignment = AlignIO.read(aln_file, 'clustal')
    return alignment

# Calcul du score de l'alignement ClustalW
def alignment_score_from_alignment(alignment, match_score=1, mismatch_penalty=-1, gap_penalty=-2):
    aligned_sequences = [list(record.seq) for record in alignment]
    return alignment_score(aligned_sequences, match_score, mismatch_penalty, gap_penalty)

# %%
# Exécuter les alignements pair par pair
pairwise_results = pairwise_alignments(sequences)

# Affichage des résultats des alignements pair par pair
print("=== Alignements pair par pair ===\n")
for result in pairwise_results:
    print(f"Alignement entre {result['seq1_id']} et {result['seq2_id']}:")
    print("Alignement Global :")
    print(result['global_alignment'][0])
    print(result['global_alignment'][1])
    print(f"Score d'alignement global : {result['global_score']}\n")
    print("Alignement Local :")
    print(result['local_alignment'][0])
    print(result['local_alignment'][1])
    print(f"Score d'alignement local : {result['local_score']}")
    print("-" * 50)

# Étape 2 : Algorithme génétique pour l'alignement multiple
best_alignment, best_score = genetic_algorithm_msa(sequences, population_size=10, generations=50)

# Convertir l'alignement en une liste de chaînes de caractères
aligned_sequences_ga = [''.join(seq) for seq in best_alignment]

# Affichage de l'alignement multiple obtenu
print("\n=== Alignement multiple obtenu par l'algorithme génétique ===\n")
for idx, seq in enumerate(aligned_sequences_ga):
    print(f"Sequence_{idx+1}:\t{seq}")

print(f"\nScore de l'alignement génétique : {best_score}")

# Étape 3 : Alignement multiple avec ClustalW
fasta_file = 'sequences.fasta'
write_fasta_file(sequences, fasta_file)
run_clustalw(fasta_file)
aln_file = 'sequences.aln'
alignment_clustalw = read_clustalw_alignment(aln_file)

# Affichage de l'alignement
print("\n=== Alignement multiple avec ClustalW ===\n")
for record in alignment_clustalw:
    print(f"{record.id}:\t{record.seq}")
score_clustalw = alignment_score_from_alignment(alignment_clustalw)
print(f"\nScore de l'alignement ClustalW : {score_clustalw}")

# Étape 4 : Comparaison des résultats
print("\n=== Comparaison des scores d'alignement ===\n")
print(f"Score de l'alignement génétique : {best_score}")
print(f"Score de l'alignement ClustalW : {score_clustalw}")

# Affichage des alignements multiples pour comparaison
print("\n=== Alignement multiple obtenu par l'algorithme génétique ===\n")
for idx, seq in enumerate(aligned_sequences_ga):
    print(f"Sequence_{idx+1}:\t{seq}")

print("\n=== Alignement multiple obtenu par ClustalW ===\n")
for record in alignment_clustalw:
    print(f"{record.id}:\t{record.seq}")
# Out:
# === Alignements pair par pair ===
#
# Alignement entre Sequence_1 et Sequence_2:
# Alignement Global :
# AGTACGCA
# --TATGC-
# Score d'alignement global : -3
#
# Alignement Local :
# TACGC
# TATGC
# Score d'alignement local : 3
# --------------------------------------------------
# Alignement entre Sequence_1 et Sequence_3:
# Alignement Global :
# AGTACGCA
# ATGACGCA
# Score d'alignement global : 4
#
# Alignement Local :
# ACGCA
# ACGCA
# Score d'alignement local : 5
# --------------------------------------------------
# Alignement entre Sequence_2 et Sequence_3:
# Alignement Global :
# -T-ATGC-
# ATGACGCA
# Score d'alignement global : -3
#
# Alignement Local :
# ATG
# ATG
# Score d'alignement local : 3
# --------------------------------------------------
# Generation 0, Best Score: -8
# Generation 27, Best Score: -4
# Generation 32, Best Score: 2
#
# === Alignement multiple obtenu par l'algorithme génétique ===
#
# Sequence_1:	ATGACGCA
# Sequence_2:	AT-T-GC-
# Sequence_3:	ATGACGCA
#
# Score de l'alignement génétique : 2
#
# === Alignement multiple avec ClustalW ===
#
# Sequence_1:	AGTACGCA
# Sequence_2:	--TATGC-
# Sequence_3:	ATGACGCA
#
# Score de l'alignement ClustalW : -4
#
# === Comparaison des scores d'alignement ===
#
# Score de l'alignement génétique : 2
# Score de l'alignement ClustalW : -4
#
# === Alignement multiple obtenu par l'algorithme génétique ===
#
# Sequence_1:	ATGACGCA
# Sequence_2:	AT-T-GC-
# Sequence_3:	ATGACGCA
#
# === Alignement multiple obtenu par ClustalW ===
#
# Sequence_1:	AGTACGCA
# Sequence_2:	--TATGC-
# Sequence_3:	ATGACGCA
